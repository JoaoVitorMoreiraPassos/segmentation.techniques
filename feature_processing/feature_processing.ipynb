# %%
import pandas as pd

# %%
out = pd.read_csv('dataset.csv')
broilers_weights = pd.read_csv('galinhas-pesos.csv')

# %%
out['target'] = -1

# %%
out.head()
# Out:
#    bbox_area  solidity  centroid-0  centroid-1  orientation  convex_area  \
# 0       7276  0.747307  100.973613  100.483020    -1.269781         5477
# 1      10712  0.940264  100.188944  100.431656    -0.200147         7734
# 2       9373  0.649843  100.981576  100.862812    -1.036508         5429
# 3       9030  0.860550  100.753751  100.654016     1.224445         6583
# 4       1764  0.794444  100.654346  100.613387    -0.012331         1260
#
#    area  filled_area  eccentricity    extent  ...  feret_diameter_max  \
# 0  4093         4093      0.898864  0.562534  ...          116.777566
# 1  7272         7272      0.370543  0.678865  ...          107.703296
# 2  3528         3528      0.749006  0.376400  ...          116.846053
# 3  5665         5665      0.714081  0.627353  ...          111.664677
# 4  1001         1001      0.982040  0.567460  ...           84.380092
#
#    inertia_tensor-0-0  inertia_tensor-0-1  inertia_tensor-1-0  \
# ...

# %%
for anilha, peso in zip(broilers_weights.anilha,  broilers_weights.peso):

    try: 
        index = out[out.label == anilha].index[0]
        out.target.loc[index] = peso
    except: continue
# Out:
# /home/mpgxc/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /home/mpgxc/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /home/mpgxc/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
out.to_csv('features_means_regression.csv', index=None)
